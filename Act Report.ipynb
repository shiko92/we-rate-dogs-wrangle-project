# %% [markdown]
# <h1><center>Act Report</center></h1>

# %% [markdown]
# <h3><center>Data Analysis Professional Nanodegree Program</center></h3>
#     <h3><center>We Rate Dogs Data
#   </center></h3>

# %% [markdown]
# This work is dedicated for **Wrangle and Analyza Data Project**. The second project in **Data Analysis Professional Nanodegree Program**.

# %% [markdown]
# ![vyjR1ftm_400x400.jpg](attachment:vyjR1ftm_400x400.jpg)

# %% [markdown]
# # Insights

# %% [markdown]
# ### Tweet with id: 744234799360020481 is the most retweeted and favorited tweet
#
#
#
# ![insight1.png](attachment:insight1.png)

# %% [markdown]
# ### Golden Retriever is the most predicted dog
#
#
# ![RMost%20Predicted%20Dog%20Type.png](attachment:RMost%20Predicted%20Dog%20Type.png)

# %% [markdown]
# ###  There is a proportional relationship between retweets counts and favourite counts
#
#
#
# ![Retweets%20&%20Favourite%20over%20time.png](attachment:Retweets%20&%20Favourite%20over%20time.png)

# %% [markdown]
# ### Even Pupper stage dogs are the most dominant in the count, but Puppo stage dogs genereated the most interaction.
#
# ![Tweet%20-%20Favorite%20per%20tweet.png](attachment:Tweet%20-%20Favorite%20per%20tweet.png)

# %% [markdown]
# ### iPhone is the most important plafrom for future updates
#
# ![Source%20vs%20tweets.png](attachment:Source%20vs%20tweets.png)

# %% [markdown]
# ### The extracted data starting from November-2015 to July-2017. The more interacion from Twitter users with this account depend on quality of tweets not the number of tweets. Followers number didn'd change so much over this period. While 2016 has the biggest total retweets and favorites but 2017 was higer in mean.
#
#
# ![Retweets%20count%20vs%20tweets.png](attachment:Retweets%20count%20vs%20tweets.png)

# %% [markdown]
# ![Tweet%20Counts%20Vs%20Favorite%20per%20tweet.png](attachment:Tweet%20Counts%20Vs%20Favorite%20per%20tweet.png)

# %% [markdown]
# # Notes
#
#
#
# * If the photo include more than one dog the rating will be much bigger than usual
# * Not dog pictures take lowest rating as well as poor quality pictures
# * the highest rate is for a picture of **Snoop Dogg**
# * some of predicted images was extracted from a video like with **tweet_id: 744234799360020481**

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">Say hello to this unbelievably well behaved squad of doggos. 204/170 would try to pet all at once <a href="https://t.co/yGQI3He3xv">pic.twitter.com/yGQI3He3xv</a></p>&mdash; WeRateDogs® (@dog_rates) <a href="https://twitter.com/dog_rates/status/731156023742988288?ref_src=twsrc%5Etfw">May 13, 2016</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
#
#
#
#
# ![CiWWhVNUYAAab_r.jpeg](attachment:CiWWhVNUYAAab_r.jpeg)

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">This is Wesley. He&#39;s clearly trespassing. Seems rather h*ckin violent too. Weaponized forehead. 3/10 wouldn&#39;t let in <a href="https://t.co/pL7wbMRW7M">pic.twitter.com/pL7wbMRW7M</a></p>&mdash; WeRateDogs® (@dog_rates) <a href="https://twitter.com/dog_rates/status/777885040357281792?ref_src=twsrc%5Etfw">September 19, 2016</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
#
#
# ![CsuaUH2WAAAWJh1.jpeg](attachment:CsuaUH2WAAAWJh1.jpeg)

# %% [markdown]
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">This is a western brown Mitsubishi terrier. Upset about leaf. Actually 2 dogs here. 7/10 would walk the shit out of <a href="https://t.co/r7mOb2m0UI">pic.twitter.com/r7mOb2m0UI</a></p>&mdash; WeRateDogs® (@dog_rates) <a href="https://twitter.com/dog_rates/status/666029285002620928?ref_src=twsrc%5Etfw">November 15, 2015</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
#
#
#
#
#
#
# ![CT42GRgUYAA5iDo.jpeg](attachment:CT42GRgUYAA5iDo.jpeg)
